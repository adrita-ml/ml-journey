# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(-1,28,28,1)/2555.0
x_test = x_test.reshape(-1,28,28,1)/2555.0

model = models.Sequential([
    layers.Conv2D(32,(3,3), activation='relu', input_shape=(28,28,1)),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(10,activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(x_train,y_train,epochs=2,validation_split=0.1)
# Out:
# Epoch 1/2
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.8343 - loss: 0.6029 - val_accuracy: 0.9667 - val_loss: 0.1208
# Epoch 2/2
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 32s 19ms/step - accuracy: 0.9628 - loss: 0.1273 - val_accuracy: 0.9763 - val_loss: 0.0834
